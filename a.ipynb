# %%
import pandas as pd

# %%
# df = pd.read_csv('data/default/generic.csv', encoding='latin-1', delimiter=';')
df = pd.read_excel('data/default/prototipo.xlsx')
df
# Out:
#     cids                                     cids_descricao          cpf  \
# 0  S22.3                                 Fratura de costela  26454020894
# 1  S82.6                         Fratura do maléolo lateral  22548868869
# 2  H59.9  Transtorno não especificado do olho e anexos p...  23540605304
# 3  S82.7                        Fraturas múltiplas da perna  74807242920
# 4    NaN                                                NaN   9890152894
# 5    K80                                        Colelitíase  14685853806
# 6  S42.2           Fratura da extremidade superior do úmero  66747589491
#
#   data_retorno data_inicio data_lancamento  estado_prestador hora_fim  \
# 0   11/07/2025  02/07/2025      15/08/2025               NaN    00:00
# 1   04/10/2025  07/07/2025      15/08/2025               NaN    00:00
# 2   13/08/2025  15/07/2025      15/08/2025               NaN    00:00
# 3   14/10/2025  17/07/2025      15/08/2025               NaN    00:00
# 4   16/01/2026  21/07/2025      15/08/2025               NaN    00:00
# 5   11/08/2025  28/07/2025      15/08/2025               NaN    00:00
# 6   12/08/2025  29/07/2025      15/08/2025               NaN    00:00
#
#   hora_inicio  identificador_prestador  local                nome_funcionario  \
# 0       00:00                      NaN    NaN  ZELANDIA MARIA DE JESUS SANTOS
# 1       00:00                      NaN    NaN                 CINTIA DA SILVA
# 2       00:00                      NaN    NaN           SUELY RODRIGUES SALES
# 3       00:00                      NaN    NaN        VENIR APARECIDA DA SILVA
# 4       00:00                      NaN    NaN      JOANA DARC DE CAMPOS SOUZA
# 5       00:00                      NaN    NaN               NATANAEL DA SILVA
# 6       00:00                      NaN    NaN       KATIA MARIA FLOR DA SILVA
#
#    nome_prestador  tipo  codigo_tipo  tipo_prestador  matricula
# 0             NaN   NaN          NaN             NaN      14873
# 1             NaN   NaN          NaN             NaN      17563
# 2             NaN   NaN          NaN             NaN      13650
# 3             NaN   NaN          NaN             NaN      16624
# 4             NaN   NaN          NaN             NaN      13299
# 5             NaN   NaN          NaN             NaN      16017
# 6             NaN   NaN          NaN             NaN      13503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cids                     6 non-null      object
#  1   cids_descricao           6 non-null      object
#  2   cpf                      7 non-null      int64
#  3   data_retorno             7 non-null      object
#  4   data_inicio              7 non-null      object
#  5   data_lancamento          7 non-null      object
#  6   estado_prestador         0 non-null      float64
#  7   hora_fim                 7 non-null      object
#  8   hora_inicio              7 non-null      object
#  9   identificador_prestador  0 non-null      float64
#  10  local                    0 non-null      float64
#  11  nome_funcionario         7 non-null      object
#  12  nome_prestador           0 non-null      float64
#  13  tipo                     0 non-null      float64
#  14  codigo_tipo              0 non-null      float64
#  15  tipo_prestador           0 non-null      float64
#  16  matricula                7 non-null      int64
# dtypes: float64(7), int64(2), object(8)
# memory usage: 1.1+ KB
