# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('data/default/generic.csv', encoding='latin-1', delimiter=';')
# df = pd.read_excel('data/default/prototipo.xlsx')
df
# Out:
#                                                 UNIDADE  \
# 0           0999 - Serviços Internos / S999 - São Paulo
# 1                 0056 - Jundiaí / RISP - Reg. Interior
# 2     0063 - POA Pontal Estaleiro / RGSU - Regional Sul
# 3              0013 - Brasília / RGCE - Regional Centro
# 4         0015 - São José Campos / RISP - Reg. Interior
# ...                                                 ...
# 2402          0057 - Vitória - ES / RGLI - Reg. Litoral
# 2403           0004 - Contagem / RGCE - Regional Centro
# 2404          0041 - Anália Franco / RGSP - Regional SP
# 2405          0016 - Ricardo Jafet / RGSP - Regional SP
# 2406             0003 - Campinas / RISP - Reg. Interior
#
#                                      SETOR  MATRICULA_FUNC DT_NASCIMENTO  \
# 0       50014801 - SI - PERFORMANCE SUPPLY        50028164    03/07/1992
# 1     50014743 - JU-RELACIONAMENTO CLIENTE        50033240    15/12/1989
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2407 entries, 0 to 2406
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   UNIDADE                     2407 non-null   object
#  1   SETOR                       2407 non-null   object
#  2   MATRICULA_FUNC              2407 non-null   int64
#  3   DT_NASCIMENTO               2407 non-null   object
#  4   SEXO                        2407 non-null   int64
#  5   TIPO_ATESTADO               2407 non-null   int64
#  6   DT_INICIO_ATESTADO          2407 non-null   object
#  7   DT_FIM_ATESTADO             2407 non-null   object
#  8   HORA_INICIO_ATESTADO        2407 non-null   object
#  9   HORA_FIM_ATESTADO           2407 non-null   object
#  10  DIAS_AFASTADOS              2407 non-null   int64
#  11  HORAS_AFASTADO              2407 non-null   object
#  12  CID_PRINCIPAL               0 non-null      float64
# ...
